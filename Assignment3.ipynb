# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Question 1

# %%
df=pd.read_excel(r'C:\Users\Chithra\Downloads\iris.xlsx')
df
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Question 2

# %%
df.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# ### Question 3

# %%
df['SL'].mean()
# Out:
# 5.843333333333334

# %%
df['SW'].mean()
# Out:
# 3.0540000000000003

# %%
df['PL'].mean()
# Out:
# 3.758666666666666

# %%
df['PW'].mean()
# Out:
# 1.1986666666666668

# %% [markdown]
# ### Question 4

# %%
df.isna()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Question 5

# %% [markdown]
# #### Plot 1- Scatter plot - SL vs SW

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='SL', y='SW', hue='Classification', palette='Set1', s=100)
plt.title('Sepal Length vs. Sepal Width')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.legend(title='Classification')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Plot 2- Scatter plot - PL vs PW

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='PL', y='PW', hue='Classification', palette='Set1', s=100)
plt.title('Petal Length vs. Petal Width')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.legend(title='Classification')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Plot 3- Bar graph - SL vs PL

# %%
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.title('Bar Graph of SL vs PL')
sns.barplot(data=df,x=df['SL'],y=df['PL'],hue='Classification')
plt.xticks(rotation=90)
plt.figure(figsize=(12,6))
plt.show()
